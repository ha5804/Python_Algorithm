# %% [markdown]
# # __Array__
#
# ## `NO10807`
#
# - list.count(elem)을 통해 리스트 안의 특정 요소 횟수를 셀 수 있다.

# %%
a = int(input())
my_list = list(map(int, input().split()))
num = int(input())
print(my_list.count(num))
# Out:
# 3

# %%
a, b = map(int, input().split())
my_list = list(map(int, input().split()))

print(x for x in my_list if x < b)
# Out:
# <generator object <genexpr> at 0x104c85cb0>
